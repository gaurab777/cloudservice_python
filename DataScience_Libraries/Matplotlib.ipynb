# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Types of plots/charts

# %% [markdown]
# ## 1) Linechart

# %%
from matplotlib import pyplot as plt #OR import matplotlib.pyplot as plt
x= [1,2,3,4]
y= [12,20,9,40]
plt.plot(x,y)
plt.show()

# %%
#Adding labels on x-axis and y-axis, and title to the chart
x = [1,2,3,4]
y = [20,50,33,45]
plt.plot(x,y,color='violet')
plt.xlabel("Serial Number")
plt.ylabel("Distribution")
plt.title("My line chart")
plt.show()

# %% [markdown]
# ## 2) Scatter Plot

# %%
x = [18,18,8,14]
y = [12,7,3,9]
plt.scatter(x,y)
plt.xlabel('Age')
plt.ylabel('Class')
plt.title('My scatter plot')
plt.show()

# %%
# Scatter plot with 1000 random dots
import numpy as np

x = np.random.random(1000)
y = np.linspace(1,100,1000)

plt.scatter(x,y,color='black')
plt.show()

# %% [markdown]
# #### Creating scatter plot using a data from SCV file

# %%
import pandas as pd
df7 = pd.read_csv('emp.csv')
df7
# Out:
#      Name   Hire Date  Salary  leaves
# 0  Graham  13/02/2022   50000       1
# 1   Harry  20/01/2021  100000       5
# 2    Anna  22/05/2021  150000       8
# 3    Niel  18/11/2021  120000       5
# 4    John  21/11/2021  100000       4
# 5   Nolan   11/9/2022   75000       5

# %%
x = df7['leaves']
y = df7['Salary']
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## 3) Bar Chart (Bar Plot)

# %%
subject = ['Math','Physics','Biology','Chemistry']
marks = [90,80,88,78]
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.title('Bar Plot of a result')
plt.bar(subject,marks,color='green')
plt.show()

# %%
subjects = ['Math','Physics','Biology','Chemistry']
marks = [90,80,88,78]
plt.xlabel('Marks')
plt.ylabel('Subjects')
plt.title("Horizontal Bar")
plt.barh(subjects,marks)
plt.show()

# %% [markdown]
# ### Comparing two bar charts

# %%
plt.bar([2,3,5,7,9],[5,2,3,6,8], label="Example 1")
plt.bar([1,4,6,8,10],[6,5,8,9,6], label="Example 2", color="green")
plt.legend()
plt.xlabel("Number")
plt.ylabel("Height")
plt.title("Comparing bar graph")
plt.show()

# %% [markdown]
# ### Creating bar plt using CSV file

# %%
x = df7['Name']
y = df7['Salary']
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## 4) Histogram

# %%
import numpy as np
a = np.array([22,13,44,4,55,66,77,98,26,44,34,50,99,67,53,67,78])
plt.hist(a, bins = [0,25,50,75,100])
plt.show()

# %%
x = np.random.randint(1,100,100)
print(x)
plt.hist(x, bins=10)
plt.title('Histogram')
plt.show()
# Out:
# [13 28 31 11 64 92 74 36 37 70 70 62 10 84 42 61 12 91 52 50 20  9 69 43
#  86 78  3 16 90 32 11 60 98 63  1 63 80 29 81 20 86 51 79 21 72 17 20 97
#  65 49 52 94  2 69 54 34 56 84  3 21 50 20 72 68 94 73 54 63 76 82 34 53
#  71 42 61 40 21 49 96 26 77 90 80 17 21 59 99 11 73  5 53 90 77 53 55 87
#  41 17 40 84]

# %% [markdown]
# #### Creating histogram using csv file

# %%
df8 = pd.read_csv('cricket.csv')
print(df8)
# Out:
#     Delivery  Score_ind  Score_pk
# 0        0.1          0         0
# 1        0.2          1         0
# 2        0.3          1         4
# 3        0.4          4         4
# 4        0.5          0         1
# 5        0.6          1         2
# 6        1.1          0         4
# 7        1.2          0         6
# 8        1.3          0         2
# 9        1.4          2         4
# 10       1.5          1         6
# 11       1.6          0         1
# 12       2.1          0         0
# 13       2.2          1         0
# 14       2.3          2         4
# 15       2.4          0         6
# 16       2.5          1         6
# 17       2.6          4         0
# 18       3.1          4         0
# 19       3.2          1         0
# 20       3.3          1         1
# 21       3.4          0         1
# 22       3.5          0         1
# 23       3.6          0         1

# %%
Score_ind = df8['Score_ind']
Score_pk = df8['Score_pk']
plt.hist([Score_ind,Score_pk], color=['orange','green'])
plt.show()

# %% [markdown]
# ## 5) Area Plot/Chart

# %%
x= [1,2,3,4]
y= [10,12,4,17]
plt.fill_between(x,y)
plt.xlabel('series')
plt.ylabel('Age')
plt.title('Area chart')
plt.show()

# %% [markdown]
# ## 6) Pie Chart

# %%
cars = ['BMW','Merc','Audi','Volkswagen','Porsche']
data = [35,28,22,33,25]
plt.pie(data, labels = cars)
plt.title('German Car Brands')
plt.show()

# %% [markdown]
# ## 7) Boxplot

# %%
from matplotlib import pyplot as plt

data1 = [100,120,140,150,180]
plt.boxplot(data1)
plt.show()

# %% [markdown]
# ## 8) Contour Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0,3.0,100) #Generating 100 numbers
ylist = np.linspace(-3.0,3.0,100) #Generating 100 numbers
X, Y = np.meshgrid(xlist,ylist)#Creating meshgrid
Z = np.sqrt(X**2 + Y**2)
cp = plt.contourf(X,Y,Z)
plt.colorbar(cp) #Adding a colorbar to a plot
plt.show()

# %% [markdown]
# ##
